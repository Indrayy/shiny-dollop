# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# 10.1 HOw to Think About Grouping Data and Operations

df = pd.DataFrame({'key1' : ['a', 'a', None, 'b', 'b', 'a', 
                            None],
                   'key2' : pd.Series([1, 2, 1, 2, 1, None, 1],
                                       dtype='Int64'),
                   'data1' : np.random.standard_normal(7),
                   'data2' : np.random.standard_normal(7)}
                   ).set_index(['key1', 'key2'])

df
# Out:
#               data1     data2
# key1 key2
# a    1    -0.585981  0.205379
#      2     0.539226  0.081889
# NaN  1    -0.763522  0.768955
# b    2     0.322188 -0.556899
#      1    -0.189294 -0.576052
# a    <NA> -1.503336 -0.667041
# NaN  1     1.074801  1.196778

# %%
grouped = df['data1'].groupby(df.index.get_level_values('key1'))

grouped

# %%
grouped.mean()
# Out:
# key1
# a   -0.516697
# b    0.066447
# Name: data1, dtype: float64

# %%
means = df['data1'].groupby([df.index.get_level_values('key1'),
                             df.index.get_level_values('key2')]).mean()
means
# Out:
# key1  key2
# a     1      -0.585981
#       2       0.539226
# b     1      -0.189294
#       2       0.322188
# Name: data1, dtype: float64

# %%
means.unstack()
# Out:
# key2         1         2
# key1
# a    -0.585981  0.539226
# b    -0.189294  0.322188

# %%
states = np.array(['Chiori','Yae Miko','Yae Miko','Chiori',
                  'Chiori','Yae Miko','Chiori']
                  )
years = [2024, 2023, 2024, 2024, 2025, 2024, 2025]

df['data1'].groupby([states, years]).mean()
# Out:
# Chiori    2024   -0.131897
#           2025    0.442754
# Yae Miko  2023    0.539226
#           2024   -1.133429
# Name: data1, dtype: float64

# %%
df.groupby('key1').mean()
# Out:
#          data1     data2
# key1
# a    -0.516697 -0.126591
# b     0.066447 -0.566476

# %%
df.groupby('key2').mean()
# Out:
#          data1     data2
# key2
# 1    -0.115999  0.398765
# 2     0.430707 -0.237505

# %%
df.groupby(['key1', 'key2']).mean()
# Out:
#               data1     data2
# key1 key2
# a    1    -0.585981  0.205379
#      2     0.539226  0.081889
# b    1    -0.189294 -0.576052
#      2     0.322188 -0.556899

# %%
df.groupby([states, years]).mean()
# Out:
#                   data1     data2
# Chiori   2024 -0.131897 -0.175760
#          2025  0.442754  0.310363
# Yae Miko 2023  0.539226  0.081889
#          2024 -1.133429  0.050957

# %%
df.groupby(['key1', 'key2']).size()
# Out:
# key1  key2
# a     1       1
#       2       1
# b     1       1
#       2       1
# dtype: int64

# %%
df.groupby('key1', dropna=False ).size()
# Out:
# key1
# a      3
# b      2
# NaN    2
# dtype: int64

# %%
df.groupby(['key1', 'key2'], dropna=False ).size()
# Out:
# key1  key2
# a     1       1
#       2       1
#       <NA>    1
# b     1       1
#       2       1
# NaN   1       2
# dtype: int64

# %%
df.groupby('key1').count()
# Out:
#       data1  data2
# key1
# a         3      3
# b         2      2

# %%
df.groupby('key2').count()
# Out:
#       data1  data2
# key2
# 1         4      4
# 2         2      2

# %%
df.groupby(['key1', 'key2']).count()
# Out:
#            data1  data2
# key1 key2
# a    1         1      1
#      2         1      1
# b    1         1      1
#      2         1      1

# %%
# Iteration over groups
for name, group in df.groupby('key1'):
    print(name)
    print(group)
# Out:
# a
#               data1     data2
# key1 key2
# a    1    -0.585981  0.205379
#      2     0.539226  0.081889
#      <NA> -1.503336 -0.667041
# b
#               data1     data2
# key1 key2
# b    2     0.322188 -0.556899
#      1    -0.189294 -0.576052

# %%
for (k1, k2), group in df.groupby(['key1', 'key2']):
    print((k1, k2))
    print(group)
# Out:
# ('a', np.int64(1))
#               data1     data2
# key1 key2
# a    1    -0.585981  0.205379
# ('a', np.int64(2))
#               data1     data2
# key1 key2
# a    2     0.539226  0.081889
# ('b', np.int64(1))
#               data1     data2
# key1 key2
# b    1    -0.189294 -0.576052
# ('b', np.int64(2))
#               data1     data2
# key1 key2
# b    2     0.322188 -0.556899

# %%
pieces = {name: group for name, group in df.groupby('key1')}

pieces['b']
# Out:
#               data1     data2
# key1 key2
# b    2     0.322188 -0.556899
#      1    -0.189294 -0.576052

# %%
grouped = df.groupby({'key1': 'key', 
                      'key2': 'key',
                      'data1': 'value',
                      'data2': 'value'}, axis='columns')
# Out:
# C:\Users\NITRO\AppData\Local\Temp\ipykernel_15852\471624870.py:1: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   grouped = df.groupby({'key1': 'key',

# %%
for group_key, group_values in grouped:
    print(group_key)
    print(group_values)
# Out:
# value
#               data1     data2
# key1 key2
# a    1    -0.585981  0.205379
#      2     0.539226  0.081889
# NaN  1    -0.763522  0.768955
# b    2     0.322188 -0.556899
#      1    -0.189294 -0.576052
# a    <NA> -1.503336 -0.667041
# NaN  1     1.074801  1.196778

# %%
# Selection of columns
# Subset of columns
grouped = df.groupby(['key1', 'key2'])[['data1', 'data2']]
grouped.mean()
# Out:
#               data1     data2
# key1 key2
# a    1    -0.585981  0.205379
#      2     0.539226  0.081889
# b    1    -0.189294 -0.576052
#      2     0.322188 -0.556899

# %%
df.groupby('key1')['data1']
df.groupby('key1')['data2']

# %%
df['data1'].groupby(df.index.get_level_values('key1'))
df[['data2']].groupby(df.index.get_level_values('key1'))

# %%
df.groupby(['key1', 'key2'])[['data2']].mean()
# Out:
#               data2
# key1 key2
# a    1     0.205379
#      2     0.081889
# b    1    -0.576052
#      2    -0.556899

# %%
s_grouped = df.groupby(['key1', 'key2'])[['data2']]

s_grouped

# %%
s_grouped.mean()
# Out:
#               data2
# key1 key2
# a    1     0.205379
#      2     0.081889
# b    1    -0.576052
#      2    -0.556899

# %%
# Grouping with Dictionaries and Series
wifes = pd.DataFrame(np.random.standard_normal ((5, 5)),
                     columns=['istri pertama', 'istri kedua',
                              'istri ketiga', 'istri keempat', 'istri kelima'],
                     index = ['Ning', 'Ei', 'Navia', 'Chiori','Yae Miko'])

# %%
wifes.iloc[2:3, [1,2]] = np.nan # add NaN values for testing

wifes
# Out:
#           istri pertama  istri kedua  istri ketiga  istri keempat  \
# Ning          -1.414274     1.277294      0.332248      -0.166088
# Ei            -0.577407    -2.675079     -1.182742      -1.850849
# Navia          1.254306          NaN           NaN       0.054553
# Chiori         0.305259    -0.279730      0.344075      -0.916953
# Yae Miko      -1.244987    -0.405918      0.684434      -0.133024
#
#           istri kelima
# Ning         -0.194009
# Ei            0.480561
# Navia         0.760515
# Chiori       -1.337501
# Yae Miko      0.487600

# %%
mapping = {'istri pertama': 'golden',
           'istri kedua'  : 'thunder',
           'istri ketiga' : 'platinum',
           'istri keempat': 'diamond',
           'istri kelima' : 'emerald'}

wifes.rename(columns=mapping)
# Out:
#             golden   thunder  platinum   diamond   emerald
# Ning     -1.414274  1.277294  0.332248 -0.166088 -0.194009
# Ei       -0.577407 -2.675079 -1.182742 -1.850849  0.480561
# Navia     1.254306       NaN       NaN  0.054553  0.760515
# Chiori    0.305259 -0.279730  0.344075 -0.916953 -1.337501
# Yae Miko -1.244987 -0.405918  0.684434 -0.133024  0.487600

# %%
mapping1 = {'istri pertama': 'golden',
            'istri kedua'  : 'golden',
            'istri ketiga' : 'emerald',
            'istri keempat': 'emerald',
            'istri kelima' : 'golden',
            'istri keenam' : 'diamond'}
wifes.rename(columns=mapping1)
# Out:
#             golden    golden   emerald   emerald    golden
# Ning     -1.414274  1.277294  0.332248 -0.166088 -0.194009
# Ei       -0.577407 -2.675079 -1.182742 -1.850849  0.480561
# Navia     1.254306       NaN       NaN  0.054553  0.760515
# Chiori    0.305259 -0.279730  0.344075 -0.916953 -1.337501
# Yae Miko -1.244987 -0.405918  0.684434 -0.133024  0.487600

# %%
by_column = wifes.groupby(mapping1, axis='columns').sum()
# Out:
# C:\Users\NITRO\AppData\Local\Temp\ipykernel_15852\2125482768.py:1: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   by_column = wifes.groupby(mapping1, axis='columns').sum()

# %%
by_column
# Out:
#            emerald    golden
# Ning      0.166160 -0.330989
# Ei       -3.033591 -2.771925
# Navia     0.054553  2.014820
# Chiori   -0.572879 -1.311972
# Yae Miko  0.551411 -1.163305

# %%
map_series = pd.Series(mapping1)

map_series
# Grouping with DataFrame
# Out:
# istri pertama     golden
# istri kedua       golden
# istri ketiga     emerald
# istri keempat    emerald
# istri kelima      golden
# istri keenam     diamond
# dtype: object

# %%
wifes.groupby(map_series, axis='columns').count()
# Out:
# C:\Users\NITRO\AppData\Local\Temp\ipykernel_15852\1070440427.py:1: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   wifes.groupby(map_series, axis='columns').count()
#           emerald  golden
# Ning            2       3
# Ei              2       3
# Navia           1       2
# Chiori          2       3
# Yae Miko        2       3

# %%
wifes.groupby(len).sum()
# Out:
#    istri pertama  istri kedua  istri ketiga  istri keempat  istri kelima
# 2      -0.577407    -2.675079     -1.182742      -1.850849      0.480561
# 4      -1.414274     1.277294      0.332248      -0.166088     -0.194009
# 5       1.254306     0.000000      0.000000       0.054553      0.760515
# 6       0.305259    -0.279730      0.344075      -0.916953     -1.337501
# 8      -1.244987    -0.405918      0.684434      -0.133024      0.487600

# %%
key_list = ['mendesah', 'mendesah', 'mendesah',
            'menjepit', 'menjepit']

wifes.groupby([len, key_list]).min()
# Out:
#             istri pertama  istri kedua  istri ketiga  istri keempat  \
# 2 mendesah      -0.577407    -2.675079     -1.182742      -1.850849
# 4 mendesah      -1.414274     1.277294      0.332248      -0.166088
# 5 mendesah       1.254306          NaN           NaN       0.054553
# 6 menjepit       0.305259    -0.279730      0.344075      -0.916953
# 8 menjepit      -1.244987    -0.405918      0.684434      -0.133024
#
#             istri kelima
# 2 mendesah      0.480561
# 4 mendesah     -0.194009
# 5 mendesah      0.760515
# 6 menjepit     -1.337501
# 8 menjepit      0.487600

# %%
wifes.groupby([len, key_list], axis='columns').min()
# Out:
# C:\Users\NITRO\AppData\Local\Temp\ipykernel_15852\2741715542.py:1: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   wifes.groupby([len, key_list], axis='columns').min()
#                 11        12                  13
#           mendesah  mendesah  menjepit  mendesah  menjepit
# Ning      1.277294  0.332248 -0.194009 -1.414274 -0.166088
# Ei       -2.675079 -1.182742  0.480561 -0.577407 -1.850849
# Navia          NaN       NaN  0.760515  1.254306  0.054553
# Chiori   -0.279730  0.344075 -1.337501  0.305259 -0.916953
# Yae Miko -0.405918  0.684434  0.487600 -1.244987 -0.133024

# %%
# Grouping by Index Levels

ranjang_istri = pd.MultiIndex.from_arrays(
    [['mendesah', 'mendesah', 'mendesah','menjepit', 'menjepit'],
     ['Navia', 'Ei', 'Chiori','Ning', 'Yae Miko']],
      names=['sex appeals', 'wifes'])

# %%
ranjang_df = pd.DataFrame(np.random.standard_normal((4, 5)),
                            columns=ranjang_istri)

# %%
ranjang_df  
# Grouping by Index Levels
# Out:
# sex appeals  mendesah                      menjepit
# wifes           Navia        Ei    Chiori      Ning  Yae Miko
# 0            2.077612 -1.035141 -0.689685  0.118969  1.779661
# 1            1.375787  1.560302  1.442555  0.295963 -0.787344
# 2            0.739539 -0.489014 -0.330560  0.085492 -0.761080
# 3            0.515582 -0.606490  1.176550  0.562697  1.147461

# %%
ranjang_df.groupby(level='sex appeals', axis='columns').count()
# Out:
# C:\Users\NITRO\AppData\Local\Temp\ipykernel_15852\550927601.py:1: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   ranjang_df.groupby(level='sex appeals', axis='columns').count()
# sex appeals  mendesah  menjepit
# 0                   3         2
# 1                   3         2
# 2                   3         2
# 3                   3         2

# %%
# 10.2 Data Aggregation and Group Operations

# any, all - Returns True if any or all of 
#            the values in the group are True

# count - Returns the number of non-NA values in the group
#         (equivalent to len(group))

# cummin, cummax - Returns the cumulative minimum or maximum
#                  of the group

# cumsum - Returns the cumulative sum of the group
# cumprod - Returns the cumulative product of the group
# first, last - Returns the first or last value in the group
# max, min - Returns the maximum or minimum value in the group
# mean, median - Returns the mean or median of the group
# nunique - Returns the number of unique values in the group
# prod - Returns the product of the values in the group
# size - Returns the size of the group (equivalent to len(group))
# nth - Returns the nth row of the group
# ohlc - Returns the open, high, low, and close values of the group
# std, var - Returns the standard deviation or variance of the group
# sum - Returns the sum of the values in the group
# quantile - Returns the nth quantile of the group
# sem - Returns the standard error of the mean of the group
# rank - Returns the ranks of the values in the group

# %%
df
# Out:
#               data1     data2
# key1 key2
# a    1    -0.585981  0.205379
#      2     0.539226  0.081889
# NaN  1    -0.763522  0.768955
# b    2     0.322188 -0.556899
#      1    -0.189294 -0.576052
# a    <NA> -1.503336 -0.667041
# NaN  1     1.074801  1.196778

# %%
grouped = df.groupby('key1')
grouped['data1'].nsmallest(2)
# Out:
# key1  key1  key2
# a     a     <NA>   -1.503336
#             1      -0.585981
# b     b     1      -0.189294
#             2       0.322188
# Name: data1, dtype: float64

# %%
def peak_to_peak(arr):
    return arr.max() - arr.min()

grouped.agg(peak_to_peak)
# Out:
#          data1     data2
# key1
# a     2.042563  0.872420
# b     0.511482  0.019153

# %%
grouped.describe()
# Out:
#      data1                                                              \
#      count      mean       std       min       25%       50%       75%
# key1
# a      3.0 -0.516697  1.023042 -1.503336 -1.044659 -0.585981 -0.023377
# b      2.0  0.066447  0.361672 -0.189294 -0.061423  0.066447  0.194318
#
#                data2                                                    \
#            max count      mean       std       min       25%       50%
# key1
# a     0.539226   3.0 -0.126591  0.472099 -0.667041 -0.292576  0.081889
# b     0.322188   2.0 -0.566476  0.013543 -0.576052 -0.571264 -0.566476
#
#
#            75%       max
# key1
# a     0.143634  0.205379
# b    -0.561688 -0.556899

# %%
tips = pd.read_csv('tips.csv')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips['tip_pct'] = tips['tip'] / tips['total_bill']

tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size   tip_pct
# 0       16.99  1.01  Female     No  Sun  Dinner     2  0.059447
# 1       10.34  1.66    Male     No  Sun  Dinner     3  0.160542
# 2       21.01  3.50    Male     No  Sun  Dinner     3  0.166587
# 3       23.68  3.31    Male     No  Sun  Dinner     2  0.139780
# 4       24.59  3.61  Female     No  Sun  Dinner     4  0.146808

# %%
grouped1 = tips.groupby(['day', 'smoker'])

grouped_pct = grouped1['tip_pct']

grouped_pct.agg(['mean', 'std'])
# Out:
#                  mean       std
# day  smoker
# Fri  No      0.151650  0.028123
#      Yes     0.174783  0.051293
# Sat  No      0.158048  0.039767
#      Yes     0.147906  0.061375
# Sun  No      0.160113  0.042347
#      Yes     0.187250  0.154134
# Thur No      0.160298  0.038774
#      Yes     0.163863  0.039389

# %%
grouped_pct.agg(['mean', 'std', peak_to_peak])
# Out:
#                  mean       std  peak_to_peak
# day  smoker
# Fri  No      0.151650  0.028123      0.067349
#      Yes     0.174783  0.051293      0.159925
# Sat  No      0.158048  0.039767      0.235193
#      Yes     0.147906  0.061375      0.290095
# Sun  No      0.160113  0.042347      0.193226
#      Yes     0.187250  0.154134      0.644685
# Thur No      0.160298  0.038774      0.193350
#      Yes     0.163863  0.039389      0.151240

# %%
grouped_pct.agg([('average', 'mean'),
                 ('std_dev', np.std),])
# Out:
# C:\Users\NITRO\AppData\Local\Temp\ipykernel_15852\143478526.py:1: FutureWarning: The provided callable <function std at 0x00000281FE8000E0> is currently using SeriesGroupBy.std. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "std" instead.
#   grouped_pct.agg([('average', 'mean'),
#               average   std_dev
# day  smoker
# Fri  No      0.151650  0.028123
#      Yes     0.174783  0.051293
# Sat  No      0.158048  0.039767
#      Yes     0.147906  0.061375
# Sun  No      0.160113  0.042347
#      Yes     0.187250  0.154134
# Thur No      0.160298  0.038774
#      Yes     0.163863  0.039389

# %%
function = ['count', 'mean', 'max']

result = grouped1[['tip_pct', 'total_bill']].agg(function)

result
# Out:
#             tip_pct                     total_bill
#               count      mean       max      count       mean    max
# day  smoker
# Fri  No           4  0.151650  0.187735          4  18.420000  22.75
#      Yes         15  0.174783  0.263480         15  16.813333  40.17
# Sat  No          45  0.158048  0.291990         45  19.661778  48.33
#      Yes         42  0.147906  0.325733         42  21.276667  50.81
# Sun  No          57  0.160113  0.252672         57  20.506667  48.17
#      Yes         19  0.187250  0.710345         19  24.120000  45.35
# Thur No          45  0.160298  0.266312         45  17.113111  41.19
#      Yes         17  0.163863  0.241255         17  19.190588  43.11

# %%
result['tip_pct']
# Out:
#              count      mean       max
# day  smoker
# Fri  No          4  0.151650  0.187735
#      Yes        15  0.174783  0.263480
# Sat  No         45  0.158048  0.291990
#      Yes        42  0.147906  0.325733
# Sun  No         57  0.160113  0.252672
#      Yes        19  0.187250  0.710345
# Thur No         45  0.160298  0.266312
#      Yes        17  0.163863  0.241255

# %%
ftupple = [('average', 'mean'),
           ('Variance', np.var)]

grouped1[['tip_pct', 'total_bill']].agg(ftupple)
# Out:
# C:\Users\NITRO\AppData\Local\Temp\ipykernel_15852\3310425565.py:4: FutureWarning: The provided callable <function var at 0x00000281FE800220> is currently using SeriesGroupBy.var. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "var" instead.
#   grouped1[['tip_pct', 'total_bill']].agg(ftupple)
#               tip_pct           total_bill
#               average  Variance    average    Variance
# day  smoker
# Fri  No      0.151650  0.000791  18.420000   25.596333
#      Yes     0.174783  0.002631  16.813333   82.562438
# Sat  No      0.158048  0.001581  19.661778   79.908965
#      Yes     0.147906  0.003767  21.276667  101.387535
# Sun  No      0.160113  0.001793  20.506667   66.099980
#      Yes     0.187250  0.023757  24.120000  109.046044
# Thur No      0.160298  0.001503  17.113111   59.625081
#      Yes     0.163863  0.001551  19.190588   69.808518

# %%
grouped1.agg({'tip' : np.max,
             'size': 'sum'})
# Out:
# C:\Users\NITRO\AppData\Local\Temp\ipykernel_15852\1314321061.py:1: FutureWarning: The provided callable <function max at 0x00000281FE7E7560> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   grouped1.agg({'tip' : np.max,
#                tip  size
# day  smoker
# Fri  No       3.50     9
#      Yes      4.73    31
# Sat  No       9.00   115
#      Yes     10.00   104
# Sun  No       6.00   167
#      Yes      6.50    49
# Thur No       6.70   112
#      Yes      5.00    40

# %%
grouped1.agg({'tip_pct' : ['min', 'max', 'mean', 'std'],
              'size' : 'sum'})
# Out:
#               tip_pct                               size
#                   min       max      mean       std  sum
# day  smoker
# Fri  No      0.120385  0.187735  0.151650  0.028123    9
#      Yes     0.103555  0.263480  0.174783  0.051293   31
# Sat  No      0.056797  0.291990  0.158048  0.039767  115
#      Yes     0.035638  0.325733  0.147906  0.061375  104
# Sun  No      0.059447  0.252672  0.160113  0.042347  167
#      Yes     0.065660  0.710345  0.187250  0.154134   49
# Thur No      0.072961  0.266312  0.160298  0.038774  112
#      Yes     0.090014  0.241255  0.163863  0.039389   40

# %%
# Returning Aggregated Data Without Row Indexes

# Select only numeric columns for aggregation
numeric_cols = tips.select_dtypes(include='number').columns
tips.groupby(['day', 'smoker'], as_index=False)[numeric_cols].mean()
# Out:
#     day smoker  total_bill       tip      size   tip_pct
# 0   Fri     No   18.420000  2.812500  2.250000  0.151650
# 1   Fri    Yes   16.813333  2.714000  2.066667  0.174783
# 2   Sat     No   19.661778  3.102889  2.555556  0.158048
# 3   Sat    Yes   21.276667  2.875476  2.476190  0.147906
# 4   Sun     No   20.506667  3.167895  2.929825  0.160113
# 5   Sun    Yes   24.120000  3.516842  2.578947  0.187250
# 6  Thur     No   17.113111  2.673778  2.488889  0.160298
# 7  Thur    Yes   19.190588  3.030000  2.352941  0.163863

# %%
# 10.3 Apply: General split-apply-combine
# This section is a placeholder for 
# the application of the split-apply-combine strategy.

# %%
def top(df, n=5, column='tip_pct'):
    return df.sort_values(column, ascending=False)[:n]

# Example usage of the top function
top(tips, n=5, column='tip_pct')
# Out:
#      total_bill   tip     sex smoker  day    time  size   tip_pct
# 172        7.25  5.15    Male    Yes  Sun  Dinner     2  0.710345
# 178        9.60  4.00  Female    Yes  Sun  Dinner     2  0.416667
# 67         3.07  1.00  Female    Yes  Sat  Dinner     1  0.325733
# 232       11.61  3.39    Male     No  Sat  Dinner     2  0.291990
# 183       23.17  6.50    Male    Yes  Sun  Dinner     4  0.280535

# %%
tips.groupby('smoker').apply(top, n=3, column='tip_pct')
# Out:
# C:\Users\NITRO\AppData\Local\Temp\ipykernel_15852\795261144.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   tips.groupby('smoker').apply(top, n=3, column='tip_pct')
#             total_bill   tip     sex smoker   day    time  size   tip_pct
# smoker
# No     232       11.61  3.39    Male     No   Sat  Dinner     2  0.291990
#        149        7.51  2.00    Male     No  Thur   Lunch     2  0.266312
#        51        10.29  2.60  Female     No   Sun  Dinner     2  0.252672
# Yes    172        7.25  5.15    Male    Yes   Sun  Dinner     2  0.710345
#        178        9.60  4.00  Female    Yes   Sun  Dinner     2  0.416667
#        67         3.07  1.00  Female    Yes   Sat  Dinner     1  0.325733

# %%
tips.groupby(['smoker', 'day']).apply(top, n=1, column='total_bill')
# Out:
# C:\Users\NITRO\AppData\Local\Temp\ipykernel_15852\4096842605.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   tips.groupby(['smoker', 'day']).apply(top, n=1, column='total_bill')
#                  total_bill    tip     sex smoker   day    time  size  \
# smoker day
# No     Fri  94        22.75   3.25  Female     No   Fri  Dinner     2
#        Sat  212       48.33   9.00    Male     No   Sat  Dinner     4
#        Sun  156       48.17   5.00    Male     No   Sun  Dinner     6
#        Thur 142       41.19   5.00    Male     No  Thur   Lunch     5
# Yes    Fri  95        40.17   4.73    Male    Yes   Fri  Dinner     4
#        Sat  170       50.81  10.00    Male    Yes   Sat  Dinner     3
#        Sun  182       45.35   3.50    Male    Yes   Sun  Dinner     3
#        Thur 197       43.11   5.00  Female    Yes  Thur   Lunch     4
#
#                   tip_pct
# smoker day
# No     Fri  94   0.142857
#        Sat  212  0.186220
#        Sun  156  0.103799
#        Thur 142  0.121389
# Yes    Fri  95   0.117750
#        Sat  170  0.196812
#        Sun  182  0.077178
#        Thur 197  0.115982

# %%
result1 = tips.groupby('smoker')['tip_pct'].describe()

result1
# Out:
#         count      mean       std       min       25%       50%       75%  \
# smoker
# No      151.0  0.159328  0.039910  0.056797  0.136906  0.155625  0.185014
# Yes      93.0  0.163196  0.085119  0.035638  0.106771  0.153846  0.195059
#
#              max
# smoker
# No      0.291990
# Yes     0.710345

# %%
result1.unstack('smoker')
# Out:
#        smoker
# count  No        151.000000
#        Yes        93.000000
# mean   No          0.159328
#        Yes         0.163196
# std    No          0.039910
#        Yes         0.085119
# min    No          0.056797
#        Yes         0.035638
# 25%    No          0.136906
#        Yes         0.106771
# 50%    No          0.155625
#        Yes         0.153846
# 75%    No          0.185014
#        Yes         0.195059
# max    No          0.291990
#        Yes         0.710345
# dtype: float64

# %%
def f(group):
    return group.describe()

grouped1.apply(f)

# this is a placeholder for the application of 
# the split-apply-combine strategy
# when you invoke the apply method like described above,
# it is a shortcut for applying a function to each group
# and returning a DataFrame with the results
# Out:
# C:\Users\NITRO\AppData\Local\Temp\ipykernel_15852\1429740544.py:4: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped1.apply(f)
#                    total_bill       tip  size   tip_pct
# day  smoker
# Fri  No     count    4.000000  4.000000  4.00  4.000000
#             mean    18.420000  2.812500  2.25  0.151650
#             std      5.059282  0.898494  0.50  0.028123
#             min     12.460000  1.500000  2.00  0.120385
#             25%     15.100000  2.625000  2.00  0.137239
# ...                       ...       ...   ...       ...
# Thur Yes    min     10.340000  2.000000  2.00  0.090014
#             25%     13.510000  2.000000  2.00  0.148038
#             50%     16.470000  2.560000  2.00  0.153846
#             75%     19.810000  4.000000  2.00  0.194837
#             max     43.110000  5.000000  4.00  0.241255
#
# [64 rows x 4 columns]

# %%
# Suppressing the Group Keys
# If you want to suppress the group keys in the result, 
# you can use the `as_index=False` parameter in the groupby method

tips.groupby('smoker', group_keys=False).apply(top, n=3, 
                                               column='tip_pct')
# Out:
# C:\Users\NITRO\AppData\Local\Temp\ipykernel_15852\196260741.py:5: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   tips.groupby('smoker', group_keys=False).apply(top, n=3,
#      total_bill   tip     sex smoker   day    time  size   tip_pct
# 232       11.61  3.39    Male     No   Sat  Dinner     2  0.291990
# 149        7.51  2.00    Male     No  Thur   Lunch     2  0.266312
# 51        10.29  2.60  Female     No   Sun  Dinner     2  0.252672
# 172        7.25  5.15    Male    Yes   Sun  Dinner     2  0.710345
# 178        9.60  4.00  Female    Yes   Sun  Dinner     2  0.416667
# 67         3.07  1.00  Female    Yes   Sat  Dinner     1  0.325733

# %%
# Quantile & Bucket Analysis

frame = pd.DataFrame({'data1': np.random.standard_normal(100),
                      'data2': np.random.standard_normal(100)
                        })

frame.head()
# Out:
#       data1     data2
# 0  0.128991 -0.034256
# 1  0.833791  0.663276
# 2  1.937529 -1.239211
# 3  1.053727 -0.991841
# 4 -0.606454 -0.399486

# %%
quartile_1 = pd.cut(frame['data1'], 4)
quartile_1.head(10)

# pd.cut is used to segment and sort data values into bins.
# It is often used to convert continuous data into categorical data.
# You can use pd.cut to create quantiles or buckets of data.

# pd.cut(frame['data1'], 4) creates 4 equal-width bins
# based on the values in the 'data1' column of the DataFrame 'frame'.
# Out:
# 0    (-0.169, 1.112]
# 1    (-0.169, 1.112]
# 2     (1.112, 2.393]
# 3    (-0.169, 1.112]
# 4    (-1.45, -0.169]
# 5    (-0.169, 1.112]
# 6    (-1.45, -0.169]
# 7    (-1.45, -0.169]
# 8    (-0.169, 1.112]
# 9    (-2.736, -1.45]
# Name: data1, dtype: category
# Categories (4, interval[float64, right]): [(-2.736, -1.45] < (-1.45, -0.169] < (-0.169, 1.112] < (1.112, 2.393]]

# %%
def get_stat(group):
    return pd.DataFrame(
        {'min': group.min(), 'max': group.max(),
           'count': group.count(), 'mean': group.mean()})

grouped2 = frame.groupby(quartile_1)
# Out:
# C:\Users\NITRO\AppData\Local\Temp\ipykernel_15852\3004443430.py:6: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped2 = frame.groupby(quartile_1)

# %%
grouped2.apply(get_stat)
# Out:
#                             min       max  count      mean
# data1
# (-2.736, -1.45] data1 -2.731047 -1.486938      8 -1.916766
#                 data2 -1.475669  1.963106      8  0.040416
# (-1.45, -0.169] data1 -1.407033 -0.274652     38 -0.667735
#                 data2 -1.985620  1.916023     38  0.010740
# (-0.169, 1.112] data1 -0.166359  1.110294     38  0.459772
#                 data2 -3.492017  1.791813     38 -0.092361
# (1.112, 2.393]  data1  1.160443  2.392897     16  1.702143
#                 data2 -2.555724  2.005471     16  0.053587

# %%
grouped.agg(['min', 'max', 'count','mean'])
# Out:
#          data1                               data2
#            min       max count      mean       min       max count      mean
# key1
# a    -1.503336  0.539226     3 -0.516697 -0.667041  0.205379     3 -0.126591
# b    -0.189294  0.322188     2  0.066447 -0.576052 -0.556899     2 -0.566476

# %%
# Example: Filing Missing Values with Group-Specific Values

# This section is a placeholder for the example of 
# filling missing values

s= pd.Series(np.random.standard_normal(6))
s[::2] = np.nan  # introduce NaN values for testing

# %%
s
# Out:
# 0         NaN
# 1    1.096930
# 2         NaN
# 3    0.264391
# 4         NaN
# 5   -0.968794
# dtype: float64

# %%
s.fillna(s.mean())
# Out:
# 0    0.130842
# 1    1.096930
# 2    0.130842
# 3    0.264391
# 4    0.130842
# 5   -0.968794
# dtype: float64

# %%
wifes = ['Chiori','Yae Miko','Fischl','Furina',
          'Barbara','Kuki Shinobu','Lan Yan', 'Mizuki']

group_key = ['Inazuma', 'Inazuma', 'Mondstadt', 'Inazuma',
             'Mondstadt', 'Mondstadt', 'Mondstadt', 'Mondstadt']

data = pd.Series(np.random.standard_normal(8), index=wifes)

# %%
data
# Out:
# Chiori          0.420044
# Yae Miko        1.417904
# Fischl         -0.016121
# Furina         -2.102161
# Barbara         1.462583
# Kuki Shinobu   -0.472003
# Lan Yan        -0.368176
# Mizuki         -1.129890
# dtype: float64

# %%
data[['Fischl', 'Kuki Shinobu', 'Mizuki']] = np.nan  
# introduce NaN values for testing

data
# Out:
# Chiori          0.420044
# Yae Miko        1.417904
# Fischl               NaN
# Furina         -2.102161
# Barbara         1.462583
# Kuki Shinobu         NaN
# Lan Yan        -0.368176
# Mizuki               NaN
# dtype: float64

# %%
data.groupby(group_key).size()

# this is a placeholder for the example of 
# filling missing values with group-specific values

# data.groupby(group_key).size() is used to count the number of
# occurrences of each group in the 'group_key' list.
# Out:
# Inazuma      3
# Mondstadt    5
# dtype: int64

# %%
data.groupby(group_key).count()

# data.groupby(group_key).count() is used to count the number of 
# non-NaN values in each group defined by 'group_key'.
# Out:
# Inazuma      3
# Mondstadt    2
# dtype: int64

# %%
data.groupby(group_key).mean()
# Out:
# Inazuma     -0.088071
# Mondstadt    0.547204
# dtype: float64

# %%
def fill_mean(group):
    return group.fillna(group.mean()) # This function fills NaN values in 
                                      # a group with the mean of that group
  
data.groupby(group_key).apply(fill_mean)
# Out:
# Inazuma    Chiori          0.420044
#            Yae Miko        1.417904
#            Furina         -2.102161
# Mondstadt  Fischl          0.547204
#            Barbara         1.462583
#            Kuki Shinobu    0.547204
#            Lan Yan        -0.368176
#            Mizuki          0.547204
# dtype: float64

# %%
fill_values = {'Inazuma': 0.5, 'Mondstadt': -1}

def fill_with_values(group):
    return group.fillna(fill_values[group.name])

data.groupby(group_key).apply(fill_with_values)
# Out:
# Inazuma    Chiori          0.420044
#            Yae Miko        1.417904
#            Furina         -2.102161
# Mondstadt  Fischl         -1.000000
#            Barbara         1.462583
#            Kuki Shinobu   -1.000000
#            Lan Yan        -0.368176
#            Mizuki         -1.000000
# dtype: float64

# %%
suits = ['Hearts', 'Diamonds', 'Clubs', 'Spades']
card_val = (list(range(1, 11)) + [10]*3) *4 
# this creates a list of card values

base_names = ['A'] + list(range(2, 11)) + ['J', 'K', 'Q']
cards = []
for suit in suits:
    cards.extend(str(num) + ' of ' + suit for num in base_names)

deck = pd.Series(card_val, index=cards)

# %%
deck.head(13)
# Out:
# A of Hearts      1
# 2 of Hearts      2
# 3 of Hearts      3
# 4 of Hearts      4
# 5 of Hearts      5
# 6 of Hearts      6
# 7 of Hearts      7
# 8 of Hearts      8
# 9 of Hearts      9
# 10 of Hearts    10
# J of Hearts     10
# K of Hearts     10
# Q of Hearts     10
# dtype: int64

# %%
def draw(deck, n=5):
    return deck.sample(n=n, replace=False)
# Example usage of the draw function
draw(deck, n=5)
# Out:
# 6 of Hearts       6
# J of Hearts      10
# 2 of Clubs        2
# 6 of Diamonds     6
# 3 of Diamonds     3
# dtype: int64

# %%
def get_suit(card):
    return card.split(' ')[-1]  
# Extract the suit from the card string
deck.groupby(get_suit).apply(draw, n=2)
# Out:
# Clubs     Q of Clubs        10
#           6 of Clubs         6
# Diamonds  4 of Diamonds      4
#           10 of Diamonds    10
# Hearts    8 of Hearts        8
#           K of Hearts       10
# Spades    2 of Spades        2
#           10 of Spades      10
# dtype: int64

# %%
deck.groupby(get_suit, group_keys=False).apply(draw, n=2)
# Out:
# 8 of Clubs        8
# 4 of Clubs        4
# 6 of Diamonds     6
# 3 of Diamonds     3
# 10 of Hearts     10
# 8 of Hearts       8
# A of Spades       1
# 6 of Spades       6
# dtype: int64

# %%
# Example: Group Wieghted Average and Correlation
# This section is a placeholder for the example of
# group weighted average and correlation

# %%
df_1 = pd.DataFrame({'category' : ['a', 'a', 'a', 'a',
                                   'b', 'b', 'b', 'b'],
                     'values' : np.random.standard_normal(8),
                     'weights' : np.random.uniform(size=8)})

df_1
# Out:
#   category    values   weights
# 0        a -0.429768  0.911791
# 1        a  0.215446  0.281583
# 2        a  0.446725  0.516517
# 3        a  1.064104  0.331937
# 4        b  0.906385  0.622519
# 5        b -0.287269  0.026086
# 6        b  0.778797  0.713553
# 7        b -0.075672  0.650329

# %%
grouped.head()
# Out:
#               data1     data2
# key1 key2
# a    1    -0.585981  0.205379
#      2     0.539226  0.081889
# b    2     0.322188 -0.556899
#      1    -0.189294 -0.576052
# a    <NA> -1.503336 -0.667041

# %%
grouped1.head(1)
# Out:
#      total_bill   tip     sex smoker   day    time  size   tip_pct
# 0         16.99  1.01  Female     No   Sun  Dinner     2  0.059447
# 19        20.65  3.35    Male     No   Sat  Dinner     3  0.162228
# 56        38.01  3.00    Male    Yes   Sat  Dinner     4  0.078927
# 77        27.20  4.00    Male     No  Thur   Lunch     4  0.147059
# 80        19.44  3.00    Male    Yes  Thur   Lunch     2  0.154321
# 90        28.97  3.00    Male    Yes   Fri  Dinner     2  0.103555
# 91        22.49  3.50    Male     No   Fri  Dinner     2  0.155625
# 164       17.51  3.00  Female    Yes   Sun  Dinner     2  0.171331

# %%
grouped2.head(2)
# Out:
#        data1     data2
# 0   0.128991 -0.034256
# 1   0.833791  0.663276
# 2   1.937529 -1.239211
# 4  -0.606454 -0.399486
# 6  -0.693589  1.102326
# 9  -2.294898  0.206131
# 24 -1.685811 -1.475669
# 32  1.501688  1.712146

# %%
s_grouped.head()
# Out:
#               data2
# key1 key2
# a    1     0.205379
#      2     0.081889
# b    2    -0.556899
#      1    -0.576052

# %%
grouped = df_1.groupby('category')

# %%
def get_wavg(group):
    return np.average(group['values'],
                       weights=group['weights']) 

grouped.apply(get_wavg)
# Out:
# C:\Users\NITRO\AppData\Local\Temp\ipykernel_15852\53840498.py:5: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped.apply(get_wavg)
# category
# a    0.123793
# b    0.528326
# dtype: float64

# %%
close_px = pd.read_csv('stock_px.csv',
                       parse_dates=True, index_col=0)

# %%
close_px.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2214 entries, 2003-01-02 to 2011-10-14
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AAPL    2214 non-null   float64
#  1   MSFT    2214 non-null   float64
#  2   XOM     2214 non-null   float64
#  3   SPX     2214 non-null   float64
# dtypes: float64(4)
# memory usage: 86.5 KB

# %%
close_px.tail()
# Out:
#               AAPL   MSFT    XOM      SPX
# 2011-10-10  388.81  26.94  76.28  1194.89
# 2011-10-11  400.29  27.00  76.27  1195.54
# 2011-10-12  402.19  26.96  77.16  1207.25
# 2011-10-13  408.43  27.18  76.37  1203.66
# 2011-10-14  422.00  27.27  78.11  1224.58

# %%
def spx_corr(group):
    return group.corrwith(group['SPX'])

rets = close_px.pct_change().dropna()

# %%
def get_year(x):
    return x.year

by_year = rets.groupby(get_year)
by_year.apply(lambda x: x.corrwith(x['SPX']))
# Out:
#           AAPL      MSFT       XOM  SPX
# 2003  0.541124  0.745174  0.661265  1.0
# 2004  0.374283  0.588531  0.557742  1.0
# 2005  0.467540  0.562374  0.631010  1.0
# 2006  0.428267  0.406126  0.518514  1.0
# 2007  0.508118  0.658770  0.786264  1.0
# 2008  0.681434  0.804626  0.828303  1.0
# 2009  0.707103  0.654902  0.797921  1.0
# 2010  0.710105  0.730118  0.839057  1.0
# 2011  0.691931  0.800996  0.859975  1.0

# %%
# other methods like 
by_year.apply(spx_corr)
# Out:
#           AAPL      MSFT       XOM  SPX
# 2003  0.541124  0.745174  0.661265  1.0
# 2004  0.374283  0.588531  0.557742  1.0
# 2005  0.467540  0.562374  0.631010  1.0
# 2006  0.428267  0.406126  0.518514  1.0
# 2007  0.508118  0.658770  0.786264  1.0
# 2008  0.681434  0.804626  0.828303  1.0
# 2009  0.707103  0.654902  0.797921  1.0
# 2010  0.710105  0.730118  0.839057  1.0
# 2011  0.691931  0.800996  0.859975  1.0

# %%
def corr_aapl_msft(group):
    return group['AAPL'].corr(group['MSFT'])

by_year.apply(corr_aapl_msft)
# this is computing the correlation between AAPL and MSFT
# for each year in the 'by_year' group
# Out:
# 2003    0.480868
# 2004    0.259024
# 2005    0.300093
# 2006    0.161735
# 2007    0.417738
# 2008    0.611901
# 2009    0.432738
# 2010    0.571946
# 2011    0.581987
# dtype: float64

# %%
# Example: Group-Wise Linear Regression

import statsmodels.api as sm

# %%
def regress(data, yvar=None, xvars=None):
    Y = data[yvar]
    X = data[xvars]
    X['intercept'] = 1
    result = sm.OLS(Y, X).fit()
    return result.params

# %%
by_year.apply(regress, yvar='AAPL', xvars =['SPX'])
# Out:
#            SPX  intercept
# 2003  1.195406   0.000710
# 2004  1.363463   0.004201
# 2005  1.766415   0.003246
# 2006  1.645496   0.000080
# 2007  1.198761   0.003438
# 2008  0.968016  -0.001110
# 2009  0.879103   0.002954
# 2010  1.052608   0.001261
# 2011  0.806605   0.001514

# %%
df_2 = pd.DataFrame({'key': ['a', 'b', 'c']*4,
                     'value' : np.arange(12.)})

df_2
# Out:
#    key  value
# 0    a    0.0
# 1    b    1.0
# 2    c    2.0
# 3    a    3.0
# 4    b    4.0
# 5    c    5.0
# 6    a    6.0
# 7    b    7.0
# 8    c    8.0
# 9    a    9.0
# 10   b   10.0
# 11   c   11.0

# %%
g = df_2.groupby('key')['value']

g.mean()

# copilot where are you inline?
# Out:
# key
# a    4.5
# b    5.5
# c    6.5
# Name: value, dtype: float64

# %%
def get_mean(group):
    return group.mean()

g.transform(get_mean)
# Out:
# 0     4.5
# 1     5.5
# 2     6.5
# 3     4.5
# 4     5.5
# 5     6.5
# 6     4.5
# 7     5.5
# 8     6.5
# 9     4.5
# 10    5.5
# 11    6.5
# Name: value, dtype: float64

# %%
def times_two(group):
    return group*2

g.transform(times_two)
# Out:
# 0      0.0
# 1      2.0
# 2      4.0
# 3      6.0
# 4      8.0
# 5     10.0
# 6     12.0
# 7     14.0
# 8     16.0
# 9     18.0
# 10    20.0
# 11    22.0
# Name: value, dtype: float64

# %%
def ge_ranks(group):
    return group.rank(ascending=False)

g.transform(ge_ranks)
# Out:
# 0     4.0
# 1     4.0
# 2     4.0
# 3     3.0
# 4     3.0
# 5     3.0
# 6     2.0
# 7     2.0
# 8     2.0
# 9     1.0
# 10    1.0
# 11    1.0
# Name: value, dtype: float64

# %%
def normalize(x):
    return (x-x.mean()) / x.std()

g.transform(normalize)
# Out:
# 0    -1.161895
# 1    -1.161895
# 2    -1.161895
# 3    -0.387298
# 4    -0.387298
# 5    -0.387298
# 6     0.387298
# 7     0.387298
# 8     0.387298
# 9     1.161895
# 10    1.161895
# 11    1.161895
# Name: value, dtype: float64

# %%
g.apply(normalize)
# Out:
# key
# a    0    -1.161895
#      3    -0.387298
#      6     0.387298
#      9     1.161895
# b    1    -1.161895
#      4    -0.387298
#      7     0.387298
#      10    1.161895
# c    2    -1.161895
#      5    -0.387298
#      8     0.387298
#      11    1.161895
# Name: value, dtype: float64

# %%
g.transform('mean')
# Out:
# 0     4.5
# 1     5.5
# 2     6.5
# 3     4.5
# 4     5.5
# 5     6.5
# 6     4.5
# 7     5.5
# 8     6.5
# 9     4.5
# 10    5.5
# 11    6.5
# Name: value, dtype: float64

# %%
normalized = (df_2['value'] - g.transform('mean')) / g.transform('std')

normalized
# Out:
# 0    -1.161895
# 1    -1.161895
# 2    -1.161895
# 3    -0.387298
# 4    -0.387298
# 5    -0.387298
# 6     0.387298
# 7     0.387298
# 8     0.387298
# 9     1.161895
# 10    1.161895
# 11    1.161895
# Name: value, dtype: float64

# %%
# 10.5 Pivot Tables and Cross-Tabulation

tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size   tip_pct
# 0       16.99  1.01  Female     No  Sun  Dinner     2  0.059447
# 1       10.34  1.66    Male     No  Sun  Dinner     3  0.160542
# 2       21.01  3.50    Male     No  Sun  Dinner     3  0.166587
# 3       23.68  3.31    Male     No  Sun  Dinner     2  0.139780
# 4       24.59  3.61  Female     No  Sun  Dinner     4  0.146808

# %%
tips.pivot_table(index=['day', 'smoker'], values=numeric_cols)
# Out:
#                  size       tip   tip_pct  total_bill
# day  smoker
# Fri  No      2.250000  2.812500  0.151650   18.420000
#      Yes     2.066667  2.714000  0.174783   16.813333
# Sat  No      2.555556  3.102889  0.158048   19.661778
#      Yes     2.476190  2.875476  0.147906   21.276667
# Sun  No      2.929825  3.167895  0.160113   20.506667
#      Yes     2.578947  3.516842  0.187250   24.120000
# Thur No      2.488889  2.673778  0.160298   17.113111
#      Yes     2.352941  3.030000  0.163863   19.190588

# %%
tips.pivot_table(index=['time', 'day'], columns='smoker',
                 values=['tip_pct', 'size'])
# Out:
#                  size             tip_pct
# smoker             No       Yes        No       Yes
# time   day
# Dinner Fri   2.000000  2.222222  0.139622  0.165347
#        Sat   2.555556  2.476190  0.158048  0.147906
#        Sun   2.929825  2.578947  0.160113  0.187250
#        Thur  2.000000       NaN  0.159744       NaN
# Lunch  Fri   3.000000  1.833333  0.187735  0.188937
#        Thur  2.500000  2.352941  0.160311  0.163863

# %%
tips.pivot_table(index=['time', 'day'], columns='smoker',
                 values=['tip_pct', 'size'], margins=True)

# This passing margin = True si Adding all row & columns labels, 
# with corresponding values being the group statistics for 
# all data within single tier
# Out:
#                  size                       tip_pct
# smoker             No       Yes       All        No       Yes       All
# time   day
# Dinner Fri   2.000000  2.222222  2.166667  0.139622  0.165347  0.158916
#        Sat   2.555556  2.476190  2.517241  0.158048  0.147906  0.153152
#        Sun   2.929825  2.578947  2.842105  0.160113  0.187250  0.166897
#        Thur  2.000000       NaN  2.000000  0.159744       NaN  0.159744
# Lunch  Fri   3.000000  1.833333  2.000000  0.187735  0.188937  0.188765
#        Thur  2.500000  2.352941  2.459016  0.160311  0.163863  0.161301
# All          2.668874  2.408602  2.569672  0.159328  0.163196  0.160803

# %%
tips.pivot_table(index=['time', 'smoker'], columns='day',
                 values= 'tip_pct', aggfunc=len, margins=True)

# The all values are means without taking into account
# smoker vs non-smoker (the All columns) or any of the 2 levels
# of grouping on the rows (the All rows)
# Out:
# day             Fri   Sat   Sun  Thur  All
# time   smoker
# Dinner No       3.0  45.0  57.0   1.0  106
#        Yes      9.0  42.0  19.0   NaN   70
# Lunch  No       1.0   NaN   NaN  44.0   45
#        Yes      6.0   NaN   NaN  17.0   23
# All            19.0  87.0  76.0  62.0  244

# %%
tips.pivot_table(index=['time', 'size','smoker'], columns='day',
                 values= 'tip_pct', fill_value=0)

# if some combinations are empty (NA, Nan) 
# you may wish to pass a fill_value
# Out:
# day                      Fri       Sat       Sun      Thur
# time   size smoker
# Dinner 1    No      0.000000  0.137931  0.000000  0.000000
#             Yes     0.000000  0.325733  0.000000  0.000000
#        2    No      0.139622  0.162705  0.168859  0.159744
#             Yes     0.171297  0.148668  0.207893  0.000000
#        3    No      0.000000  0.154661  0.152663  0.000000
#             Yes     0.000000  0.144995  0.152660  0.000000
#        4    No      0.000000  0.150096  0.148143  0.000000
#             Yes     0.117750  0.124515  0.193370  0.000000
#        5    No      0.000000  0.000000  0.206928  0.000000
#             Yes     0.000000  0.106572  0.065660  0.000000
#        6    No      0.000000  0.000000  0.103799  0.000000
# Lunch  1    No      0.000000  0.000000  0.000000  0.181728
#             Yes     0.223776  0.000000  0.000000  0.000000
#        2    No      0.000000  0.000000  0.000000  0.166005
#             Yes     0.181969  0.000000  0.000000  0.158843
#        3    No      0.187735  0.000000  0.000000  0.084246
#             Yes     0.000000  0.000000  0.000000  0.204952
#        4    No      0.000000  0.000000  0.000000  0.138919
#             Yes     0.000000  0.000000  0.000000  0.155410
#        5    No      0.000000  0.000000  0.000000  0.121389
#        6    No      0.000000  0.000000  0.000000  0.173706

# %%
# Cross-Tabulations:Crosstab

from io import StringIO

# %%
data_genshin = """ Sample Teyvat_State Elements
1.  Mondstadt Anemo
2.  Liyue Geo
3.  Mondstadt Anemo
4.  Liyue Anemo
5.  Liyue Geo
6.  Liyue Anemo
7.  Mondstadt Anemo
8.  Mondstadt Geo
9.  Liyue Anemo
10. Mondstadt Anemo
"""

# %%
data_genshin = pd.read_table(StringIO(data_genshin),
                             sep = "\s+")
data_genshin
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\NITRO\AppData\Local\Temp\ipykernel_15852\1828896371.py:2: SyntaxWarning: invalid escape sequence '\s'
#   sep = "\s+")
#    Sample Teyvat_State Elements
# 0     1.0    Mondstadt    Anemo
# 1     2.0        Liyue      Geo
# 2     3.0    Mondstadt    Anemo
# 3     4.0        Liyue    Anemo
# 4     5.0        Liyue      Geo
# 5     6.0        Liyue    Anemo
# 6     7.0    Mondstadt    Anemo
# 7     8.0    Mondstadt      Geo
# 8     9.0        Liyue    Anemo
# 9    10.0    Mondstadt    Anemo

# %%
pd.crosstab(data_genshin['Teyvat_State'],
            data_genshin['Elements'],
            margins=True)
# Out:
# Elements      Anemo  Geo  All
# Teyvat_State
# Liyue             3    2    5
# Mondstadt         4    1    5
# All               7    3   10

# %%
pd.crosstab([tips['time'],tips['day']],
             tips['smoker'],
             margins=True)

# The first 2 arguments to crosstab can each be an 
# array or Series or list of arrays
# Out:
# smoker        No  Yes  All
# time   day
# Dinner Fri     3    9   12
#        Sat    45   42   87
#        Sun    57   19   76
#        Thur    1    0    1
# Lunch  Fri     1    6    7
#        Thur   44   17   61
# All          151   93  244
